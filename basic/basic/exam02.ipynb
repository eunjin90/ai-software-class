# %%
num = 10
print(num >= 2 and num <= 9)
# Out:
# False

# %%
print(2 <= num <= 9)
# Out:
# False

# %% [markdown]
# if 조건:
#     조건이 참일수행
#
# if 조건:
#     조건이 참일때 수행
# else:
#     조건이 거짓일때 수행
#
# 4가지의 경우의 수 (ABCD 중 출력)
# if 조건1:
#     A출력
# else:   # BCD 출력
#     if 조건2:
#         B출력
#     else:   #CD출력
#         if 조건3:
#             C출력
#         else:
#             D출력
#
# if 조건1:
#     A출력
# elif 조건2:
#     B출력
# elif 조건3:
#     C출력
# else:
#     D출력
