# %%
#input() : 키보드 입력받는 함수

# 키보드 입력 방법1 
# input() : 키보드 입력받는 함수
num1 = input('첫번째 정수를 입력하세요')    # 키보드로 친 내용을 num1이라는 바구니에 담음
num2 = input('두번째 정수를 입력하세요')
#int(), float(), str() : type 변환함수

num1 = int(num1)  # '34' => 34  # 문자였던 num1에게 "너 이제부터 숫자(정수) 해!"라고 명령
num2 = int(num2)

# %%
# 키보드 입력 방법2
num1 = int(input('첫번째 정수를 입력:')) # 입력받자마자 바로 숫자로 바꿔서 담는 지름길
num2 = int(input('두번째 정수를 입력:'))

print(num1, type(num1))


num1 = int(num1)
num2 = int(num2)
# Out:
# 12 <class 'int'>

# %%
# 키보드 입력 방법3
#str = ('2026-3-9')
#print(str)
#print(str.split('-'))

# str_val = input('정수 2개를 입력하세요 ex) 12 6: ') # str = '12 6'
# print(str_val, type(str_val))

# str_list = str_val.split() #['12', '6']

# # map(int, str) : 리스트 안에 든 여러 글자들에 한꺼번에 int(숫자)로 바꿈
# # map(수행할 함수, 집합): 집합의 모든 데이터에 지정한 함수를 수행하시오
# num1, num2 = map(int, str_list) # num1, num2 = [12, 6] # 숫자로 바뀐 값들을 각각 num1과 num2에 순서대로 나눠 담음
# 여러 숫자를 한 줄에 받으려면 split()과 map()을 세트로 쓰기.

# print(num1, num2)
# # num1 = int(num1)
# # num2 = int(num2)
# # print(num1, num2)

str = input('정수 2개를 입력하세요 ex)12 6')        # str = '12 6'
print(str, type(str))
str = str.split(' ')  # ['12', '6']     # 한 줄로 들어온 것을 공백( ) 기준으로 툭 잘라서 리스트로 만듬
print(str, type(str)) 
# map(수행할함수명, 집합) : 집합의 모든 데이터에 지정한 함수를 수행하시오
num1, num2 = map(int, str)  # num1, num2 = [12, 6]
# Out:
# 12 3 <class 'str'>
# ['12', '3'] <class 'list'>

# %%
# str = input('정수 2개를 입력하세요 ex) 12 5')
# num1, num2 = map(int, str.split(' ')) #공백으로 줌

# num1, num2 = map(int, input('정수 2개를 입력하세요 ex) 12 9: ').split())
# print(num1, num2)

num1, num2 = map(int, input('정수 2개를 입력하세요 ex) 12 9').split(' '))

# %%
#출력1
print('num1 :',num1, ', num2 :',num2)
print('두 정수의 합 : ',num1+num2)
print('두 정수의 차 : ',num1-num2)
print('두 정수의 곱 : ',num1*num2)
print('두 정수의 나눗셈 : ',num1/num2)
print('두 정수의 몫 : ',num1//num2)
print('두 정수의 나머지 : ',num1%num2)
# Out:
# num1 : 12 , num2 : 9
# 두 정수의 합 :  21
# 두 정수의 차 :  3
# 두 정수의 곱 :  108
# 두 정수의 나눗셈 :  1.3333333333333333
# 두 정수의 몫 :  1
# 두 정수의 나머지 :  3

# %%
# 출력2
# num1 = 50
# num2 = 7
# #출력2
# print('num1 : ', num1, 'num2 :', num2)
# print(num1, ' + ', num2 , ' = ',(num1 + num2),sep='',end='')
# #sep = 값들 사이에 넣을 문자,end = 줄바꿈 대신 공백이 들어간 것. 출력이 끝난 뒤에 붙는 문자\n = 줄바꿈
# print(num1, '-', num1,'=', num1-num2)

# 출력2
print('num1 :' , num1,  'num2 :', num2)
print(num1,' + ', num2 , ' = ', (num1 + num2), sep='')  # sep='': 출력할 값들 사이에 공백을 넣지 말라는 뜻. (딱 붙어서 출력됨)
print(num1, '-', num2, '=', num1-num2)

# sep과 end 옵션을 쓰면 출력 모양을 세밀하게 조절할 수 있다
# Out:
# num1 : 12 num2 : 9
# 12 + 9 = 21
# 12 - 9 = 3

# %%
#출력3
#포멧문자 사용 %d %f %s
print('%d+%d=%d' %(num1,num2,num1+num2))    # %d는 정수가 들어갈 예약석. 나중에 뒤에 있는 변수들이 순서대로 들어감
print('%d %% %d=%d' %(num1,num2,num1%num2))
#% 방식 출력에서는 %가 특별한 기호라서 %를 문자로 출력하려면 두 개 써야 한다.
# Out:
# 12+9=21
# 12 % 9=3

# %%
#출력4
str = '{1}+{0}={2}'.format(num1,num2,num1+num2)
# {0}, {1}은 순서를 정하는 것. num1이 0번, num2가 1번 자리
#중괄호 {} 는 값이 들어갈 자리
#format() 안에 있는 값들이 앞에서부터 {}에 들어간다. 순서대로들어갈꺼면 비워둬도됨 {}+{}={}
print(str)
print('{}-{}={}'.format(num1,num2,num1-num2))
# Out:
# 9+12=21
# 12-9=3

# %%
#요즘 가장 많이 쓰는 방법
print(f"{num1}+{num2}={num1+num2}")
# 따옴표 앞에 f를 붙이고 중괄호 { } 안에 변수나 계산식을 바로 넣음
# Out:
# 12+9=21

# %%
# 출력5
print(f'{num1} + {num2} = {num1 + num2}')

# %%
num = 10
print(num >=2 and num <=9)  # num이 2보다 크거나 같으면서, 동시에 9보다 작거나 같니?
# Out:
# False

# %%
print(2 <= num <=9)
